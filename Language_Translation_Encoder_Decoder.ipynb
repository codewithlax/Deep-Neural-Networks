# %% [markdown]
# <a href="https://colab.research.google.com/github/codewithlax/Deep-Neural-Networks/blob/main/Language_Translation_Encoder_Decoder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Language translation using encoder-decoder (Seq-Seq)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense
import numpy as np

# %%
# !!curl -O http://www.manythings.org/anki/fra-eng.zip
# !!unzip fra-eng.zip
# Out:
# ['Archive:  fra-eng.zip',
#  'replace _about.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: ']

# %%
# Initializing variables:
batch_size = 64
epochs = 100
latent_dim = 256
num_samples = 10000 # No. of samples to train on
data_path = 'fra.txt'

# %% [markdown]
# Prepare the data

# %%
# Vectorize the data.
input_texts = []
target_texts = []
input_characters = set()
target_characters = set()
with open(data_path, "r", encoding="utf-8") as f:
    lines = f.read().split("\n")
for line in lines[: min(num_samples, len(lines) - 1)]:
    input_text, target_text, _ = line.split("\t")
    # We use "tab" as the "start sequence" character
    # for the targets, and "\n" as "end sequence" character.
    target_text = "\t" + target_text + "\n"
    input_texts.append(input_text)
    target_texts.append(target_text)
    for char in input_text:
        if char not in input_characters:
            input_characters.add(char)
    for char in target_text:
        if char not in target_characters:
            target_characters.add(char)

# %%
input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)
max_encoder_seq_length = max([len(txt) for txt in input_texts])
max_decoder_seq_length = max([len(txt) for txt in target_texts])

# %%
print("Number of samples:", len(input_texts))
print("Number of unique input tokens:", num_encoder_tokens)
print("Number of unique output tokens:", num_decoder_tokens)
print("Max sequence length for inputs:", max_encoder_seq_length)
print("Max sequence length for outputs:", max_decoder_seq_length)
# Out:
# Number of samples: 10000
# Number of unique input tokens: 70
# Number of unique output tokens: 93
# Max sequence length for inputs: 14
# Max sequence length for outputs: 59

# %%
input_token_index = dict([(char, i) for i, char in enumerate(input_characters)])
target_token_index = dict([(char, i) for i, char in enumerate(target_characters)])

encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length, num_encoder_tokens), dtype="float32"
)
decoder_input_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens), dtype="float32"
)
decoder_target_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens), dtype="float32"
)

# %%
for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.0
    encoder_input_data[i, t + 1 :, input_token_index[" "]] = 1.0
    for t, char in enumerate(target_text):
        # decoder_target_data is ahead of decoder_input_data by one timestep
        decoder_input_data[i, t, target_token_index[char]] = 1.0
        if t > 0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.0
    decoder_input_data[i, t + 1 :, target_token_index[" "]] = 1.0
    decoder_target_data[i, t:, target_token_index[" "]] = 1.0

# %% [markdown]
# Build the model

# %%
# Define an input sequence and process it.
encoder_inputs = Input(shape=(None, num_encoder_tokens))
encoder = LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)

# We discard `encoder_outputs` and only keep the states.
encoder_states = [state_h, state_c]

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = Input(shape=(None, num_decoder_tokens))

# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs, initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation="softmax")
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# %% [markdown]
# Train the model

# %%
model.compile(
    optimizer="rmsprop", loss="categorical_crossentropy", metrics=["accuracy"]
)
model.fit(
    [encoder_input_data, decoder_input_data],
    decoder_target_data,
    batch_size=batch_size,
    epochs=epochs,
    validation_split=0.2,
)
# Save model
#model.save("s2s")
# Out:
# Epoch 1/100
# 125/125 [==============================] - 11s 22ms/step - loss: 1.2048 - accuracy: 0.7323 - val_loss: 1.0823 - val_accuracy: 0.7138
# Epoch 2/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.9343 - accuracy: 0.7489 - val_loss: 0.9579 - val_accuracy: 0.7313
# Epoch 3/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.8451 - accuracy: 0.7653 - val_loss: 0.8830 - val_accuracy: 0.7470
# Epoch 4/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.7502 - accuracy: 0.7897 - val_loss: 0.7821 - val_accuracy: 0.7791
# Epoch 5/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.6740 - accuracy: 0.8061 - val_loss: 0.7254 - val_accuracy: 0.7928
# Epoch 6/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.6317 - accuracy: 0.8168 - val_loss: 0.6862 - val_accuracy: 0.8001
# Epoch 7/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.6061 - accuracy: 0.8234 - val_loss: 0.6578 - val_accuracy: 0.8068
# Epoch 8/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.5817 - accuracy: 0.8286 - val_loss: 0.6545 - val_accuracy: 0.8077
# Epoch 9/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.5619 - accuracy: 0.8345 - val_loss: 0.6274 - val_accuracy: 0.8185
# Epoch 10/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.5451 - accuracy: 0.8400 - val_loss: 0.6048 - val_accuracy: 0.8235
# Epoch 11/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.5282 - accuracy: 0.8450 - val_loss: 0.5812 - val_accuracy: 0.8331
# Epoch 12/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.5135 - accuracy: 0.8493 - val_loss: 0.5767 - val_accuracy: 0.8344
# Epoch 13/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.5004 - accuracy: 0.8534 - val_loss: 0.5595 - val_accuracy: 0.8381
# Epoch 14/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.4885 - accuracy: 0.8565 - val_loss: 0.5514 - val_accuracy: 0.8411
# Epoch 15/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.4773 - accuracy: 0.8596 - val_loss: 0.5342 - val_accuracy: 0.8445
# Epoch 16/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.4670 - accuracy: 0.8624 - val_loss: 0.5278 - val_accuracy: 0.8485
# Epoch 17/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.4568 - accuracy: 0.8649 - val_loss: 0.5148 - val_accuracy: 0.8502
# Epoch 18/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.4477 - accuracy: 0.8678 - val_loss: 0.5118 - val_accuracy: 0.8504
# Epoch 19/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.4386 - accuracy: 0.8705 - val_loss: 0.5019 - val_accuracy: 0.8532
# Epoch 20/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.4305 - accuracy: 0.8723 - val_loss: 0.5016 - val_accuracy: 0.8537
# Epoch 21/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.4229 - accuracy: 0.8749 - val_loss: 0.4933 - val_accuracy: 0.8561
# Epoch 22/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.4150 - accuracy: 0.8771 - val_loss: 0.4985 - val_accuracy: 0.8544
# Epoch 23/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.4083 - accuracy: 0.8790 - val_loss: 0.4853 - val_accuracy: 0.8585
# Epoch 24/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.4018 - accuracy: 0.8805 - val_loss: 0.4761 - val_accuracy: 0.8610
# Epoch 25/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.3956 - accuracy: 0.8824 - val_loss: 0.4728 - val_accuracy: 0.8626
# Epoch 26/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.3891 - accuracy: 0.8841 - val_loss: 0.4682 - val_accuracy: 0.8629
# Epoch 27/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.3832 - accuracy: 0.8854 - val_loss: 0.4675 - val_accuracy: 0.8632
# Epoch 28/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.3778 - accuracy: 0.8872 - val_loss: 0.4622 - val_accuracy: 0.8651
# Epoch 29/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.3724 - accuracy: 0.8885 - val_loss: 0.4576 - val_accuracy: 0.8663
# Epoch 30/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.3667 - accuracy: 0.8902 - val_loss: 0.4564 - val_accuracy: 0.8668
# Epoch 31/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.3614 - accuracy: 0.8919 - val_loss: 0.4583 - val_accuracy: 0.8666
# Epoch 32/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.3566 - accuracy: 0.8932 - val_loss: 0.4525 - val_accuracy: 0.8673
# Epoch 33/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.3509 - accuracy: 0.8950 - val_loss: 0.4492 - val_accuracy: 0.8691
# Epoch 34/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.3463 - accuracy: 0.8960 - val_loss: 0.4473 - val_accuracy: 0.8698
# Epoch 35/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.3414 - accuracy: 0.8978 - val_loss: 0.4473 - val_accuracy: 0.8689
# Epoch 36/100
# 125/125 [==============================] - 2s 17ms/step - loss: 0.3371 - accuracy: 0.8989 - val_loss: 0.4423 - val_accuracy: 0.8714
# Epoch 37/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.3325 - accuracy: 0.9001 - val_loss: 0.4437 - val_accuracy: 0.8713
# Epoch 38/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.3284 - accuracy: 0.9015 - val_loss: 0.4400 - val_accuracy: 0.8723
# Epoch 39/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.3236 - accuracy: 0.9029 - val_loss: 0.4395 - val_accuracy: 0.8728
# Epoch 40/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.3192 - accuracy: 0.9041 - val_loss: 0.4366 - val_accuracy: 0.8737
# Epoch 41/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.3148 - accuracy: 0.9056 - val_loss: 0.4358 - val_accuracy: 0.8739
# Epoch 42/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.3108 - accuracy: 0.9066 - val_loss: 0.4393 - val_accuracy: 0.8725
# Epoch 43/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.3065 - accuracy: 0.9083 - val_loss: 0.4363 - val_accuracy: 0.8744
# Epoch 44/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.3025 - accuracy: 0.9094 - val_loss: 0.4346 - val_accuracy: 0.8741
# Epoch 45/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.2986 - accuracy: 0.9104 - val_loss: 0.4337 - val_accuracy: 0.8756
# Epoch 46/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2948 - accuracy: 0.9113 - val_loss: 0.4323 - val_accuracy: 0.8752
# Epoch 47/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2909 - accuracy: 0.9128 - val_loss: 0.4332 - val_accuracy: 0.8765
# Epoch 48/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2871 - accuracy: 0.9138 - val_loss: 0.4332 - val_accuracy: 0.8765
# Epoch 49/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2834 - accuracy: 0.9148 - val_loss: 0.4321 - val_accuracy: 0.8767
# Epoch 50/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2800 - accuracy: 0.9162 - val_loss: 0.4326 - val_accuracy: 0.8765
# Epoch 51/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.2759 - accuracy: 0.9172 - val_loss: 0.4338 - val_accuracy: 0.8773
# Epoch 52/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.2722 - accuracy: 0.9184 - val_loss: 0.4329 - val_accuracy: 0.8777
# Epoch 53/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.2688 - accuracy: 0.9196 - val_loss: 0.4310 - val_accuracy: 0.8775
# Epoch 54/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.2655 - accuracy: 0.9202 - val_loss: 0.4322 - val_accuracy: 0.8775
# Epoch 55/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2623 - accuracy: 0.9209 - val_loss: 0.4314 - val_accuracy: 0.8784
# Epoch 56/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2586 - accuracy: 0.9224 - val_loss: 0.4344 - val_accuracy: 0.8780
# Epoch 57/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.2553 - accuracy: 0.9235 - val_loss: 0.4367 - val_accuracy: 0.8776
# Epoch 58/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2521 - accuracy: 0.9243 - val_loss: 0.4354 - val_accuracy: 0.8785
# Epoch 59/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2485 - accuracy: 0.9254 - val_loss: 0.4320 - val_accuracy: 0.8800
# Epoch 60/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2460 - accuracy: 0.9261 - val_loss: 0.4368 - val_accuracy: 0.8780
# Epoch 61/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.2426 - accuracy: 0.9271 - val_loss: 0.4351 - val_accuracy: 0.8797
# Epoch 62/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.2390 - accuracy: 0.9283 - val_loss: 0.4378 - val_accuracy: 0.8796
# Epoch 63/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.2361 - accuracy: 0.9291 - val_loss: 0.4403 - val_accuracy: 0.8790
# Epoch 64/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2331 - accuracy: 0.9297 - val_loss: 0.4396 - val_accuracy: 0.8793
# Epoch 65/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2303 - accuracy: 0.9303 - val_loss: 0.4378 - val_accuracy: 0.8792
# Epoch 66/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2268 - accuracy: 0.9318 - val_loss: 0.4398 - val_accuracy: 0.8805
# Epoch 67/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2240 - accuracy: 0.9327 - val_loss: 0.4434 - val_accuracy: 0.8791
# Epoch 68/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.2213 - accuracy: 0.9335 - val_loss: 0.4414 - val_accuracy: 0.8806
# Epoch 69/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.2190 - accuracy: 0.9339 - val_loss: 0.4470 - val_accuracy: 0.8797
# Epoch 70/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.2154 - accuracy: 0.9352 - val_loss: 0.4464 - val_accuracy: 0.8797
# Epoch 71/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.2131 - accuracy: 0.9358 - val_loss: 0.4487 - val_accuracy: 0.8795
# Epoch 72/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2107 - accuracy: 0.9363 - val_loss: 0.4474 - val_accuracy: 0.8801
# Epoch 73/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.2075 - accuracy: 0.9373 - val_loss: 0.4515 - val_accuracy: 0.8795
# Epoch 74/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.2048 - accuracy: 0.9382 - val_loss: 0.4530 - val_accuracy: 0.8795
# Epoch 75/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2020 - accuracy: 0.9394 - val_loss: 0.4536 - val_accuracy: 0.8795
# Epoch 76/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.1994 - accuracy: 0.9395 - val_loss: 0.4545 - val_accuracy: 0.8804
# Epoch 77/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.1969 - accuracy: 0.9403 - val_loss: 0.4590 - val_accuracy: 0.8795
# Epoch 78/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.1945 - accuracy: 0.9411 - val_loss: 0.4583 - val_accuracy: 0.8794
# Epoch 79/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.1919 - accuracy: 0.9420 - val_loss: 0.4619 - val_accuracy: 0.8800
# Epoch 80/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1895 - accuracy: 0.9425 - val_loss: 0.4648 - val_accuracy: 0.8794
# Epoch 81/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.1873 - accuracy: 0.9430 - val_loss: 0.4648 - val_accuracy: 0.8793
# Epoch 82/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.1853 - accuracy: 0.9438 - val_loss: 0.4682 - val_accuracy: 0.8789
# Epoch 83/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.1821 - accuracy: 0.9449 - val_loss: 0.4689 - val_accuracy: 0.8796
# Epoch 84/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1799 - accuracy: 0.9454 - val_loss: 0.4777 - val_accuracy: 0.8781
# Epoch 85/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1777 - accuracy: 0.9460 - val_loss: 0.4712 - val_accuracy: 0.8798
# Epoch 86/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.1757 - accuracy: 0.9467 - val_loss: 0.4738 - val_accuracy: 0.8791
# Epoch 87/100
# 125/125 [==============================] - 2s 14ms/step - loss: 0.1734 - accuracy: 0.9473 - val_loss: 0.4783 - val_accuracy: 0.8793
# Epoch 88/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1707 - accuracy: 0.9481 - val_loss: 0.4783 - val_accuracy: 0.8796
# Epoch 89/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1692 - accuracy: 0.9484 - val_loss: 0.4794 - val_accuracy: 0.8791
# Epoch 90/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.1670 - accuracy: 0.9493 - val_loss: 0.4851 - val_accuracy: 0.8789
# Epoch 91/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1647 - accuracy: 0.9499 - val_loss: 0.4874 - val_accuracy: 0.8786
# Epoch 92/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.1628 - accuracy: 0.9505 - val_loss: 0.4835 - val_accuracy: 0.8794
# Epoch 93/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1610 - accuracy: 0.9511 - val_loss: 0.4870 - val_accuracy: 0.8792
# Epoch 94/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1589 - accuracy: 0.9518 - val_loss: 0.4908 - val_accuracy: 0.8787
# Epoch 95/100
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1566 - accuracy: 0.9525 - val_loss: 0.4940 - val_accuracy: 0.8792
# Epoch 96/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.1547 - accuracy: 0.9528 - val_loss: 0.4925 - val_accuracy: 0.8794
# Epoch 97/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1528 - accuracy: 0.9534 - val_loss: 0.4997 - val_accuracy: 0.8787
# Epoch 98/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1510 - accuracy: 0.9541 - val_loss: 0.5012 - val_accuracy: 0.8790
# Epoch 99/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1494 - accuracy: 0.9543 - val_loss: 0.5048 - val_accuracy: 0.8771
# Epoch 100/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1475 - accuracy: 0.9548 - val_loss: 0.5059 - val_accuracy: 0.8781

# %% [markdown]
# Run inference (sampling):

# %%
# Define sampling models
# Restore the model and construct the encoder and decoder.
# model = keras.models.load_model("s2s")

encoder_inputs = model.input[0]  # input_1
encoder_outputs, state_h_enc, state_c_enc = model.layers[2].output  # lstm_1
encoder_states = [state_h_enc, state_c_enc]
encoder_model = Model(encoder_inputs, encoder_states)

decoder_inputs = model.input[1]  # input_2
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_lstm = model.layers[3]
decoder_outputs, state_h_dec, state_c_dec = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs
)
decoder_states = [state_h_dec, state_c_dec]
decoder_dense = model.layers[4]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs, [decoder_outputs] + decoder_states
)

# Reverse-lookup token index to decode sequences back to
# something readable.
reverse_input_char_index = dict((i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict((i, char) for char, i in target_token_index.items())


def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0, target_token_index["\t"]] = 1.0

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ""
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        if sampled_char == "\n" or len(decoded_sentence) > max_decoder_seq_length:
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.0

        # Update states
        states_value = [h, c]
    return decoded_sentence

# %%
for seq_index in range(20):
    # Take one sequence (part of the training set)
    # for trying out decoding.
    input_seq = encoder_input_data[seq_index : seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print("-")
    print("Input sentence:", input_texts[seq_index])
    print("Decoded sentence:", decoded_sentence)
# Out:
# 1/1 [==============================] - 0s 466ms/step
# 1/1 [==============================] - 0s 401ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# -
# Input sentence: Go.
# Decoded sentence: Aprands !
#
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# -
# Input sentence: Go.
# Decoded sentence: Aprands !
#
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# -
# Input sentence: Go.
# Decoded sentence: Aprands !
#
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# -
# Input sentence: Go.
# Decoded sentence: Aprands !
#
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# -
# Input sentence: Hi.
# Decoded sentence: Salut !
#
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# -
# Input sentence: Hi.
# Decoded sentence: Salut !
#
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# -
# Input sentence: Run!
# Decoded sentence: File !
#
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 44ms/step
# -
# Input sentence: Run!
# Decoded sentence: File !
#
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 66ms/step
# 1/1 [==============================] - 0s 42ms/step
# -
# Input sentence: Run!
# Decoded sentence: File !
#
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# -
# Input sentence: Run!
# Decoded sentence: File !
#
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# -
# Input sentence: Run!
# Decoded sentence: File !
#
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# -
# Input sentence: Run!
# Decoded sentence: File !
#
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# -
# Input sentence: Run!
# Decoded sentence: File !
#
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 33ms/step
# -
# Input sentence: Run!
# Decoded sentence: File !
#
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 53ms/step
# -
# Input sentence: Run.
# Decoded sentence: File !
#
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# -
# Input sentence: Run.
# Decoded sentence: File !
#
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# -
# Input sentence: Run.
# Decoded sentence: File !
#
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# -
# Input sentence: Run.
# Decoded sentence: File !
#
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# -
# Input sentence: Run.
# Decoded sentence: File !
#
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# -
# Input sentence: Run.
# Decoded sentence: File !
